# %% [markdown]
# <a href="https://colab.research.google.com/github/nithish17jan-spec/Python/blob/main/IDENTITY_OPERATOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IDENTITY OPERATOR
a="hello"
b="hello"
print(a is b)
print(a is not b)
c="python"
print(a is c)
print(a is not c)
# Out:
# True
# False
# False
# True
