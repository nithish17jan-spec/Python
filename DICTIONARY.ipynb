# %% [markdown]
# <a href="https://colab.research.google.com/github/nithish17jan-spec/Python/blob/main/DICTIONARY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dictionary
student = {
    "name": "Nithish",
    "age": 17,
    "branch": "ECE"
}

# %%
#create
d1 = {}                       # Empty dictionary
d2 = dict()                   # Empty dictionary
d3 = {"a": 1, "b": 2}         # With values

# %%
#access
d3={'a':1,'b':2}
print(d3["a"])
print(d3.get("b"))
#remove
d3.popitem()
del d3["b"]
d3.clear()
#add
d3["c"] = 3
d3["a"] = 10
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1922507776.py in <cell line: 0>()
#       5 #remove
#       6 d3.popitem()
# ----> 7 del d3["b"]
#       8 d3.clear()
#       9 #add
#
# KeyError: 'b'
