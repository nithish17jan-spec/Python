# %% [markdown]
# <a href="https://colab.research.google.com/github/nithish17jan-spec/Python/blob/main/COMPARISON_OPERATOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#RELATIONAL OPERATOR
a=10
b=20
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# False
# True
# False
# True
