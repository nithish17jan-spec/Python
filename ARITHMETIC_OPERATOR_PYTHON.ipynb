# %% [markdown]
# <a href="https://colab.research.google.com/github/nithish17jan-spec/Python/blob/main/ARITHMETIC_OPERATOR_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ARITHMETIC OPERATOR
a=10
b=5
print(a+b)
print(a-b)
print(a*b)
print(a%b)
print(a/b)
print(a//b)
print(a**b)
# Out:
# 15
# 5
# 50
# 0
# 2.0
# 2
# 100000

# %%
print(10 + 20 * 3 ** 2 // 4)
# Out:
# 55

# %%
x = 5
x += x * 2 ** 3 // 4
print(x)
# Out:
# 15

# %%
print(7 + 3 * (10 // 5) ** 2 % 3)
# Out:
# 7

# %%
print((5 + 3) * 2 ** 2 // 4 + 1)
# Out:
# 9
