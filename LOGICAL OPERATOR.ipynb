# %% [markdown]
# <a href="https://colab.research.google.com/github/nithish17jan-spec/Python/blob/main/LOGICAL%20OPERATOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#LOGICAL OPERATOR
a=1
b=0
print(a and b)
print(a or b)
print(not(a>0))
# Out:
# 0
# 1
# False
