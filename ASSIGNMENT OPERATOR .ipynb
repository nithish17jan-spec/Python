# %% [markdown]
# <a href="https://colab.research.google.com/github/nithish17jan-spec/Python/blob/main/ASSIGNMENT%20OPERATOR%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ASSIGNMENT OPERATOR
a=10
a +=1
print(a)
a -=1
print(a)
a *=1
print(a)
a /=1
print(a)
# Out:
# 11
# 10
# 10
# 10.0

# %%
x = 5
x += 2
x *= x
print(x)
# Out:
# 49
