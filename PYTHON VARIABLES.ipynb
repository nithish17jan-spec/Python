# %% [markdown]
# <a href="https://colab.research.google.com/github/nithish17jan-spec/Python/blob/main/Python_varaiables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
a=10
b=20
print("the sum of a+b is:",a+b)
# Out:
# the sum of a+b is: 30

# %%
a=int(input("Enter value of a:"))
b=int(input("Enter value of b:"))
print("The sum of a+b is:",a+b)
# Out:
# Enter value of a:10
# Enter value of b:7
# 17
