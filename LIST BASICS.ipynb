# %% [markdown]
# <a href="https://colab.research.google.com/github/nithish17jan-spec/Python/blob/main/LIST%20BASICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#LIST
list=[1,2,3,4,5]#create a list
l1=[1,2,3,1,2,3]#duplicate
l2=[1,'n',3.14]#different data type

# %%
#ACCES INDEX
num=[5,10,15,20,25,30]
print(num[0])
print(num[-1])#Negative indexing
# Out:
# 5
# 30

# %%
#multidimensional list
n=[[1,2,3],'neso',[4,5,6]]
print(n[1][3])
# Out:
# o
