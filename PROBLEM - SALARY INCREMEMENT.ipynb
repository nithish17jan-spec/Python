# %% [markdown]
# <a href="https://colab.research.google.com/github/nithish17jan-spec/Python/blob/main/PROBLEM%20-%20SALARY%20INCREMEMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
salary = 12000

if salary < 10000:
    salary += salary * 0.20
elif salary <= 20000:
    salary += salary * 0.10
else:
    salary += salary * 0.05

print("Updated Salary:", salary)
# Out:
# Updated Salary: 13200.0
